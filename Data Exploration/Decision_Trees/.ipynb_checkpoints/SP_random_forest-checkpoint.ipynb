# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import graphviz 
# might need to install -- need *both* python and system
# so use Anaconda (or pip) to install graphviz, and also https://graphviz.org/download/
# this was a non-trivial install on Mac (depends on Xcode command-line tools)
# `pip install graphviz` and `brew install graphviz`
import datetime as dt

# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import confusion_matrix, mean_squared_error, mean_absolute_error

# %%
energy_generated = pd.read_csv("../../Data/subsystem_all_dams/Energy_generated_daily_by_dam.csv.zip")
influent_flow = pd.read_csv("../../Data/subsystem_all_dams/Influent_flow_daily_by_dam.csv.zip")
energy_generated['dam'].unique()
# Out:
# array([' VOLTA GRANDE (CEMIG)', ' TRÊS MARIAS', ' TRÊS IRMÃOS',
#        ' SOBRAGI', ' SERRA DA MESA', ' SEN. JOSÉ ERMÍRIO DE MORAES',
#        ' SÃO SIMÃO (CEMIG)', ' SANTA BRANCA', ' SALTO GRANDE (CEMIG)',
#        ' RUI BARBOSA', ' ROSANA', ' PORTO COLÔMBIA', ' PEREIRA PASSOS',
#        ' PCH ESCELSA', ' PCH ENERSUL', ' PCH EMAE', ' PCH CPFL',
#        ' PCH CESP', ' PCH CERJ', ' PCH CEMIG', ' PCH CEMAT', ' PCH CELG',
#        ' PCH CEB', ' PARAIBUNA', ' NOVA PONTE', ' NILO PECANHA',
#        ' MIRANDA', ' MASCARENHAS', ' MÁRIO LOPES LEÃO', ' MARIMBONDO',
#        ' MAL. MASCARENHAS DE MORAES', ' LUIZ CARLOS BARRETO DE CARVALHO',
#        ' LUCAS NOGUEIRA GARCEZ', ' JAGUARI (CESP)', ' JAGUARA',
#        ' ITUTINGA', ' ITUMBIARA (FURNAS)', ' ITAIPU', ' ILHA DOS POMBOS',
#        ' IGARAPAVA', ' IBITINGA', ' GUILMAN - AMORIM', ' FURNAS',
#        ' FUNIL (FURNAS)', ' FONTES NOVA (A+BC+SC)', ' EUCLIDES DA CUNHA',
#        ' ESCOLA POLITÉCNICA', ' ESCOLA ENGENHARIA ALEXANDRE MACKENZIE',
#        ' ENG. SOUZA DIAS', ' ENG. SERGIO MOTA (PORTO PRIMAVERA)',
#        ' EMBORCAÇÃO', ' CORUMBÁ I (FURNAS)', ' COMPLEXO ILHA SOLTEIRA',
#        ' COMPLEXO HENRY BORDEN + pedreira + traição', ' CHAVANTES',
#        ' CANOAS II', ' CANOAS I', ' CAMARGOS', ' CACONDE',
#        ' CACHOEIRA DOURADA', ' BARRA BONITA',
#        ' ARMANDO SALLES DE OLIVEIRA', ' ARMANDO AVELLANAL LAYDNER',
#        ' ÁLVARO DE SOUZA LIMA', ' MANSO', ' SÁ CARVALHO',
#        ' PORTO ESTRELA', ' LUÍS EDUARDO MAGALHÃES', ' SANTA CLARA (CESC)',
#        ' ROSAL', ' ASSIS CHATEAUBRIAND', ' CANA BRAVA', ' Juba I',
#        ' PIRAJÚ', ' ITIQUIRA I + ITIQUIRA II', ' FUNIL (VALE-CEMIG)',
#        ' JAURU', ' GUAPORÉ (TANGARÁ)', ' QUEIMADO', ' RISOLETA NEVES',
#        ' PONTE DE PEDRA', ' AIMORÉS', ' OURINHOS', ' AMADOR AGUIAR I',
#        ' CORUMBÁ IV', ' PEIXE ANGICAL', ' PICADA', ' IRAPÉ', ' ESPORA',
#        ' AMADOR AGUIAR II', ' SALTO CURUÁ', ' SÃO SALVADOR', ' BAGUARI',
#        ' CORUMBÁ III', ' SAMUEL', ' RETIRO BAIXO', ' SALTO (RVESA)',
#        ' BARRA DOS COQUEIROS (GALB)', ' CAÇU (GALB)',
#        ' SALTO DO RIO VERDINHO', ' SERRA DO FACÃO', ' ENG. JOSÉ L. GODOY',
#        ' RONDON II', ' DARDANELOS', ' BURITI (ACEP)', ' ALTO SUCURIÚ',
#        ' PORTO DAS PEDRAS', ' SANTO ANTÔNIO (STO. ANTONIO)', ' Juba II',
#        ' SÃO JOAQUIM (ACEP)', ' SÃO JOÃO', ' FRANCISCO GROS',
#        ' CONJUNTO HIDRELETRICO PARECIS', ' JIRAU', ' SIMPLÍCIO ANTA',
#        ' SALTO BURITI', ' SALTO TRÊS DE MAIO', ' BATALHA',
#        ' ENG. JOSÉ GELÁSIO DA ROCHA',
#        ' CONJUNTO HIDRELETRICO SANTA CABECA', ' SÃO LOURENÇO (ACEP)',
#        ' QUEIXADA', ' SÃO DOMINGOS (ELETROSUL)', ' TELES PIRES',
#        ' ROCHEDO', ' ANHANGUERA', ' SANTO ANTÔNIO DO CAIAPÓ',
#        ' PCH VILHENA', ' PCH IACIARA', ' PCH JAURU-CEMAT',
#        ' PCH P. BUENO', ' PCH JI-PARANA', ' MOSQUITÃO', ' SANTA ROSA II',
#        ' SANTA GABRIELA', ' MACABU', ' AREAL (QUANTA)',
#        ' CONJUNTO HIDRELETRICO FAZENDA', ' IRARA', ' PCH AMPLA',
#        ' CONJUNTO HIDRAULICO COMPLEXO DO PRATA', ' RONDONÓPOLIS',
#        ' SAO MANOEL', ' PCH YPE', ' PCH VERDE 8', ' BARRA DO BRAÚNA',
#        ' LAJARI', ' COLÍDER', ' UHE SINOP'], dtype=object)

# %%
dict = {'TRES MARIAS',
        'TRES IRMAOS',
        'SERRA DA MESA',
        'SAO SIMAO',
        'PARAIBUNA',
        'NOVA PONTE',
        'MARIMBONDO',
        'ITUMBIARA',
        'ITAIPU',
        'I. SOLTEIRA',
        'FURNAS',
        'EMBORCACAO',
        'CHAVANTES',
        'B. BONITA',
        'S.DO FACAO',
        'BATALHA'}

# %%
energy_generated["dam"] = energy_generated["dam"].apply(name_change)
energy_generated
# Out:
#               date                    dam  energy_generated
# 0       2000-01-01   VOLTA GRANDE (CEMIG)          4.175700
# 1       2000-01-01            TRÊS MARIAS          3.213400
# 2       2000-01-01            TRÊS IRMÃOS          2.699000
# 3       2000-01-01                SOBRAGI          1.390700
# 4       2000-01-01          SERRA DA MESA         10.119800
# ...            ...                    ...               ...
# 787132  2020-12-31       AMADOR AGUIAR II          2.806157
# 787133  2020-12-31        AMADOR AGUIAR I          3.514063
# 787134  2020-12-31   ÁLVARO DE SOUZA LIMA          2.148943
# 787135  2020-12-31           ALTO SUCURIÚ          0.343235
# 787136  2020-12-31                AIMORÉS          4.219292
#
# [787137 rows x 3 columns]

# %%
energy_generated = energy_generated[energy_generated['dam'].isin(
['TRES MARIAS',
 'TRES IRMAOS',
 'SERRA DA MESA',
 'SAO SIMAO',
 'PARAIBUNA',
 'NOVA PONTE',
 'MARIMBONDO',
 'ITUMBIARA',
 'ITAIPU',
 'I. SOLTEIRA',
 'FURNAS',
 'EMBORCACAO',
 'CHAVANTES',
 'B. BONITA',
 'S.DO FACAO',
 'BATALHA']
)]

energy_generated['dam'].unique()
# Out:
# array(['ITUMBIARA', 'I. SOLTEIRA', 'B. BONITA'], dtype=object)
